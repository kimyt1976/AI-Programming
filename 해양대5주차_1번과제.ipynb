# %% [markdown]
# <a href="https://colab.research.google.com/github/kimyt1976/AI-Programming/blob/main/%ED%95%B4%EC%96%91%EB%8C%805%EC%A3%BC%EC%B0%A8_1%EB%B2%88%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#github 의 자동차 생산 자료를 읽어들인다
path = 'https://github.com/dongupak/DataML/raw/main/csv/'
file = path+'vehicle_prod.csv'
df = pd.read_csv(file, index_col=0)
#데이터 프레임에서 국가명을 제외한 숫자의 합을 구하여 Total 로 명명
sums = df.select_dtypes (np.number).sum().rename('[Total]')

means = df.select_dtypes (np.number).mean().rename('[Average]')
summean_df = df.append ([sums, means])
summean_df
# Out:
# <ipython-input-10-4ce9a2209f7b>:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   summean_df = df.append ([sums, means])
#             2007       2008       2009   2010       2011
# China       7.71   7.950000  11.960000  15.84  16.330000
# EU         19.02  17.710000  15.000000  16.70  17.480000
# US         10.47   8.450000   5.580000   7.60   8.400000
# Japan      10.87  10.830000   7.550000   9.09   7.880000
# Korea       4.04   3.780000   3.450000   4.20   4.620000
# Mexico      2.01   2.050000   1.500000   2.25   2.540000
# [Total]    54.12  50.770000  45.040000  55.68  57.250000
# [Average]   9.02   8.461667   7.506667   9.28   9.541667
